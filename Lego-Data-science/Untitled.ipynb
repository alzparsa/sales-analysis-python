# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/lego-analysis/master/datasets/lego_sets.csv')
theme = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/lego-analysis/master/datasets/parent_themes.csv')

df.head(10)
# Out:
#   set_num                          name  year  num_parts    theme_name  \
# 0    00-1               Weetabix Castle  1970      471.0        Castle
# 1  0011-2             Town Mini-Figures  1978        NaN  Supplemental
# 2  0011-3    Castle 2 for 1 Bonus Offer  1987        NaN  Lion Knights
# 3  0012-1            Space Mini-Figures  1979       12.0  Supplemental
# 4  0013-1            Space Mini-Figures  1979       12.0  Supplemental
# 5  0014-1            Space Mini-Figures  1979       12.0  Supplemental
# 6  0015-1            Space Mini-Figures  1979        NaN  Supplemental
# 7  0016-1           Castle Mini Figures  1978        NaN        Castle
# 8    00-2  Weetabix Promotional House 1  1976        NaN      Building
# 9    00-3  Weetabix Promotional House 2  1976        NaN      Building
#
#   parent_theme
# 0     Legoland
# 1         Town
# 2       Castle
# 3        Space
# 4        Space
# 5        Space
# 6        Space
# 7       Castle
# 8     Legoland
# 9     Legoland

# %%
merged_df = df.merge(theme ,left_on="parent_theme", right_on="name")
merged_df.drop(columns='name_y', inplace=True)
merged_df.head()
# Out:
#   set_num                             name_x  year  num_parts theme_name  \
# 0    00-1                    Weetabix Castle  1970      471.0     Castle
# 1    00-2       Weetabix Promotional House 1  1976        NaN   Building
# 2    00-3       Weetabix Promotional House 2  1976        NaN   Building
# 3    00-4      Weetabix Promotional Windmill  1976      126.0   Building
# 4    00-7  Weetabix Promotional Lego Village  1976        NaN   Building
#
#   parent_theme   id  is_licensed
# 0     Legoland  411        False
# 1     Legoland  411        False
# 2     Legoland  411        False
# 3     Legoland  411        False
# 4     Legoland  411        False

# %%
licenced = merged_df[merged_df["is_licensed"]]
# licenced.shape[0]
licenced = licenced.dropna(subset="set_num")
# licenced.shape[0]
licenced.head()
# no_star_wars = licenced[licenced['parent_theme'] != "Star Wars"]
# no_star_wars.head()
# Out:
#       set_num                         name_x  year  num_parts  \
# 3493  10018-1                     Darth Maul  2001     1868.0
# 3494  10019-1    Rebel Blockade Runner - UCS  2001        NaN
# 3495  10026-1        Naboo Starfighter - UCS  2002        NaN
# 3496  10030-1  Imperial Star Destroyer - UCS  2002     3115.0
# 3497  10123-1                     Cloud City  2003      707.0
#
#                    theme_name parent_theme   id  is_licensed
# 3493                Star Wars    Star Wars  158         True
# 3494  Star Wars Episode 4/5/6    Star Wars  158         True
# 3495      Star Wars Episode 1    Star Wars  158         True
# 3496  Star Wars Episode 4/5/6    Star Wars  158         True
# 3497  Star Wars Episode 4/5/6    Star Wars  158         True

# %%
star_wars = licenced[licenced["parent_theme"]=="Star Wars"]
star_wars.head()
# no_star_wars = star_wars[star_wars['parent_theme'] != "Star Wars"]
# no_star_wars.head()
# Out:
#       set_num                         name_x  year  num_parts  \
# 3493  10018-1                     Darth Maul  2001     1868.0
# 3494  10019-1    Rebel Blockade Runner - UCS  2001        NaN
# 3495  10026-1        Naboo Starfighter - UCS  2002        NaN
# 3496  10030-1  Imperial Star Destroyer - UCS  2002     3115.0
# 3497  10123-1                     Cloud City  2003      707.0
#
#                    theme_name parent_theme   id  is_licensed
# 3493                Star Wars    Star Wars  158         True
# 3494  Star Wars Episode 4/5/6    Star Wars  158         True
# 3495      Star Wars Episode 1    Star Wars  158         True
# 3496  Star Wars Episode 4/5/6    Star Wars  158         True
# 3497  Star Wars Episode 4/5/6    Star Wars  158         True

# %%
res = int(100*(star_wars.shape[0]/licenced.shape[0]))

print(res)
# Out:
# 51

# %%
licenced_sorted = licenced.sort_values('year')
licenced_sorted['count'] = 1

summed_df = licenced_sorted.groupby(['year', 'parent_theme']).sum().reset_index()
max_df = summed_df.sort_values('count', ascending=False).drop_duplicates('count')

max_df.sort_values('year', inplace = True)
max_df
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_21724\4070131357.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   summed_df = licenced_sorted.groupby(['year', 'parent_theme']).sum().reset_index()
#     year                      parent_theme  num_parts     id  is_licensed  \
# 2   2000                         Star Wars     2580.0   4108           26
# 5   2002                      Harry Potter     1397.0   4674           19
# 11  2004                      Harry Potter     2217.0   3444           14
# 12  2004                         Star Wars     1659.0   3160           20
# 14  2005             Disney's Mickey Mouse       26.0    388            1
# 15  2005                      Harry Potter      994.0   1230            5
# ...
